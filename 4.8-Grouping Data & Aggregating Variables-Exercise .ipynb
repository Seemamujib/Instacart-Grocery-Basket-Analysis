# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
# set the import file path to a variable 'path'

path=r"C:\Users\19452\Desktop\Seema\Careerfoundry-Data Analytics Course\Work Area\Python Fundamentals\Nov-2023 Instacart Basket Analysis\02 Data\Prepared Data"

# import 'ords_prods_merge.pkl' from Prepared data folder
ords_prods_merge=pd.read_pickle(os.path.join(path,'ords_prods_merge.pkl'))

# %%
# create a subset of 'ords_prods_merge' dataframe with first million entries

df=ords_prods_merge[:1000000]

# %%
# check the dimensions of the subset dataframe 'df'

df.shape
# Out:
# (1000000, 17)

# %%
# check the column names of subset dataframe 'df'

df.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN       196.0                1.0        0.0
# 1                    15.0       196.0                1.0        1.0
# 2                    21.0       196.0                1.0        1.0
# 3                    29.0       196.0                1.0        1.0
# 4                    28.0       196.0                1.0        1.0
#
#   product_name  aisle_id  department_id  prices merge_flag    price_range_loc  \
# ...

# %%
# Split the data into groups (with the group being the “product_name” column) 

df.groupby('product_name')

# %%
# Split the data into groups based on “department_id.”
# Apply the agg() function to each group to obtain the mean values for the “order_number” column.

df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              19.315612
# 7.0              17.466053
# 13.0             17.753001
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             21.234049

# %%
# Rather than including the column name within square brackets, as in the example above,
# you could also set the column name off with a dot, for instance

df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4.0     19.315612
# 7.0     17.466053
# 13.0    17.753001
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    21.234049
# Name: order_number, dtype: float64

# %% [markdown]
# ### SQUARE BRACKET usage in the below example is the preferred method for groupby

# %%
# the command above could be replaced with a command that uses the mean() function to achieve the same results
# Default Role: Square brackets have no other role in Python beyond indexing, which makes it faster
# Visual Appearance: Square brackets stand out, and using them consistently will help those that may 
# look at your code down the line understand your methods.

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     19.315612
# 7.0     17.466053
# 13.0    17.753001
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    21.234049
# Name: order_number, dtype: float64

# %%
# Performing Multiple Aggregations

df.groupby('department_id').agg({'order_number':['mean','min','max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              19.315612  1.0  99.0
# 7.0              17.466053  1.0  99.0
# 13.0             17.753001  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             21.234049  1.0  99.0

# %%
# Split the data into groups based on the “user_id” column.
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
# Create a new column, “max_order,” into which you’ll place the results of your aggregation.

ords_prods_merge['max_order']=ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\19452\AppData\Local\Temp\ipykernel_70824\187751253.py:5: FutureWarning: The provided callable <function amax at 0x0000021F433E1BC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order']=ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Look at the newly created column

ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# ..        ...      ...           ...                 ...                ...
# 95  3226575.0    360.0           1.0                 5.0               12.0
# 96  1469869.0    377.0           3.0                 5.0               17.0
# 97  1927023.0    387.0           2.0                 4.0               10.0
# 98   858092.0    420.0           4.0                 1.0               19.0
# 99   119314.0    420.0           5.0                 3.0               19.0
#
# ...

# %%
# This command tells pandas not to assign any options regarding the maximum number of rows to display. For ex, when using
# head() function to display more records say, head(150).  All 150 rows would display if the below code is run

pd.options.display.max_rows=None

# %%
# Look at the newly created column

ords_prods_merge.head(100)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# 5   3367565.0      1.0           6.0                 2.0                7.0
# 6    550135.0      1.0           7.0                 1.0                9.0
# 7   3108588.0      1.0           8.0                 1.0               14.0
# 8   2295261.0      1.0           9.0                 1.0               16.0
# 9   2550362.0      1.0          10.0                 4.0                8.0
# 10  2968173.0     15.0          15.0                 1.0                9.0
# ...

# %%
# Deriving Columns with loc()
# create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value.

ords_prods_merge.loc[ords_prods_merge['max_order']>40,'loyalty_flag']='Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order']<=40) & (ords_prods_merge['max_order']>10),'loyalty_flag']='Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order']<=10,'loyalty_flag']='New customer'
# Out:
# C:\Users\19452\AppData\Local\Temp\ipykernel_70824\2496868371.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['max_order']>40,'loyalty_flag']='Loyal customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# NaN                       11
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id','loyalty_flag','order_number','max_order']].head(60)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0       1.0  Regular customer           1.0       11.0
# 1       1.0  Regular customer           2.0       11.0
# 2       1.0  Regular customer           3.0       11.0
# 3       1.0  Regular customer           4.0       11.0
# 4       1.0  Regular customer           5.0       11.0
# 5       1.0  Regular customer           6.0       11.0
# 6       1.0  Regular customer           7.0       11.0
# 7       1.0  Regular customer           8.0       11.0
# 8       1.0  Regular customer           9.0       11.0
# 9       1.0  Regular customer          10.0       11.0
# 10     15.0  Regular customer          15.0       23.0
# 11     15.0  Regular customer          17.0       23.0
# 12     15.0  Regular customer          18.0       23.0
# 13     15.0  Regular customer          21.0       23.0
# 14     15.0  Regular customer          22.0       23.0
# 15     19.0      New customer           2.0       10.0
# ...
